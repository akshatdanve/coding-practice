# %% [markdown]
# <a href="https://colab.research.google.com/github/akshatdanve/coding-practice/blob/main/Lexical%20Analyzer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB TEST LEXICAL ANALYZER QUESTION

# %%
#@title Install Flex and Bison *prerqeuisites*
# !sudo apt install flex bison
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# bison is already the newest version (2:3.8.2+dfsg-1build1).
# flex is already the newest version (2.6.4-8build2).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.

# %%
#@title Lex code - program.l
# %%writefile program.l

# %{
#include <stdio.h>
#include <stdlib.h>
%}

DIGIT   [0-9]
ID      [a-zA-Z][a-zA-Z0-9]*

%%

{DIGIT}+ { printf("Integer: %s\n", yytext); }

{DIGIT}+"."{DIGIT}+ { printf("Float: %s\n", yytext); }

"int"|"main"|"return"|"if"|"then"|"begin"|"end"|"procedure"|"function" { printf("Keyword: %s\n", yytext); }

{ID} { printf("Identifier: %s\n", yytext); }

"+"|"-"|"*"|"/" { printf("Operator: %s\n", yytext); }

","|";" { printf("Symbol: %s\n", yytext); }

"//".* { }

[ \t\n]+ { }

. { printf("Invalid: %s\n", yytext); }

%%

int yywrap() {
    return 1;
}

int main() {
    FILE *fp;
    char filename[50];

    printf("Enter file name: ");
    scanf("%s", filename);

    fp = fopen(filename, "r");
    if (fp == NULL) {
        printf("Cannot open file\n");
        return 1;
    }

    yyin = fp;
    yylex();

    fclose(fp);
    return 0;
}
# Out:
# Overwriting program.l

# %%
#@title Input file - input.txt
# %%writefile input.txt

#include <stdio.h>

int main() {
    int a[10][10], transpose[10][10], r, c;

    printf("Enter rows and columns: ");
    scanf("%d %d", &r, &c);

    // assigning elements to the matrix
    printf("\nEnter matrix elements:\n");
    for (int i = 0; i < r; ++i) {
        for (int j = 0; j < c; ++j) {
            printf("Enter element a%d%d: ", i + 1, j + 1);
            scanf("%d", &a[i][j]);   // FIX: added &
        }
    }

    // computing the transpose
    for (int i = 0; i < r; ++i) {
        for (int j = 0; j < c; ++j) {
            transpose[j][i] = a[i][j];
        }
    }

    return 0;
}
# Out:
# Writing input.txt

# %%
#@title Shell Execution
# %%shell

flex program.l
gcc lex.yy.c
./a.out
# Out:
# Enter file name: input.txt
# Invalid: #
# Identifier: include
# Invalid: <
# Identifier: stdio
# Invalid: .
# Identifier: h
# Invalid: >
# Keyword: int
# Keyword: main
# Invalid: (
# Invalid: )
# Invalid: {
# Keyword: int
# Identifier: a
# Invalid: [
# Integer: 10
# Invalid: ]
# Invalid: [
# Integer: 10
# Invalid: ]
# Symbol: ,
# Identifier: transpose
# Invalid: [
# Integer: 10
# Invalid: ]
# Invalid: [
# Integer: 10
# Invalid: ]
# Symbol: ,
# Identifier: r
# Symbol: ,
# Identifier: c
# Symbol: ;
# Identifier: printf
# Invalid: (
# Invalid: "
# Identifier: Enter
# Identifier: rows
# Identifier: and
# Identifier: columns
# Invalid: :
# Invalid: "
# Invalid: )
# Symbol: ;
# Identifier: scanf
# Invalid: (
# Invalid: "
# Invalid: %
# Identifier: d
# Invalid: %
# Identifier: d
# Invalid: "
# Symbol: ,
# Invalid: &
# Identifier: r
# Symbol: ,
# Invalid: &
# Identifier: c
# Invalid: )
# Symbol: ;
# Identifier: printf
# Invalid: (
# Invalid: "
# Invalid: \
# Identifier: nEnter
# ...
